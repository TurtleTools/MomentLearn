# %% [markdown]
# ##

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import torch
from time import time
from MomentLearn import utils
from MomentLearn import model as model_utils
from MomentLearn.model import LinearMoment, ContrastiveLearn, LSTMMoment, sample_double_proteins_with_sim_dist, loss_func
import prody as pd
import matplotlib.pyplot as plt
from caretta.score_functions import get_caretta_score
from caretta.multiple_alignment import tm_score
from caretta import superposition_functions, helper, multiple_alignment
import umap
from caretta import dynamic_time_warping as dtw

# %%
# %load_ext autoreload
# %autoreload 2

# %%
X_names, mapk_pdb_id_to_class = utils.get_example_metadata()
class_mapping = {"JNK": 0, "Erk": 1, "p38": 2}
mapping = [class_mapping[mapk_pdb_id_to_class[k]] for k in X_names]

# %%
start_time = time()
pdbs = []
for i, (pdb_id, chain) in enumerate(X_names):
    if i > 0 and i % 50 == 0:
        print(f"{i} proteins fetched in {(time() - start_time):.2f} seconds")
    pdbs.append(pd.parsePDB(pdb_id, chain=chain))
# Out:
# @> PDB file is found in working directory (3o2m.pdb).
# @> 2935 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3o2m.pdb).
# @> 2935 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4eh8.pdb.gz).
# @> 2778 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4eh2.pdb).
# @> 2842 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4eh7.pdb.gz).
# @> 2788 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4eh5.pdb.gz).
# @> 2783 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4dli.pdb.gz).
# @> 2861 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4eh3.pdb.gz).
# @> 2784 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4eh6.pdb.gz).
# @> 2825 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4eh4.pdb.gz).
# @> 2753 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4eh9.pdb.gz).
# @> 2783 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4e8a.pdb.gz).
# @> 2679 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4ehv.pdb.gz).
# @> 2936 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6qdz.pdb.gz).
# @> 2862 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6qe1.pdb.gz).
# @> 2869 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3k3i.pdb.gz).
# @> 3080 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3hll.pdb.gz).
# @> 2970 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3hl7.pdb.gz).
# @> 3004 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3hp2.pdb.gz).
# @> 3017 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2yis.pdb.gz).
# @> 2949 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3hp5.pdb.gz).
# @> 2897 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3k3j.pdb.gz).
# @> 2865 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2yiw.pdb.gz).
# @> 2909 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3roc.pdb.gz).
# @> 3051 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4e6c.pdb.gz).
# @> 2763 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4zth.pdb.gz).
# @> 2912 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4ewq.pdb.gz).
# @> 3029 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4f9y.pdb.gz).
# @> 3097 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4fa2.pdb.gz).
# @> 2963 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4f9w.pdb.gz).
# @> 2970 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4r3c.pdb.gz).
# @> 2936 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3hvc.pdb.gz).
# @> 2874 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3new.pdb.gz).
# @> 2700 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3c5u.pdb.gz).
# @> 2854 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2rg6.pdb.gz).
# @> 3068 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4e6a.pdb.gz).
# @> 2754 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4dlj.pdb.gz).
# @> 2803 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5o8v.pdb.gz).
# @> 2708 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5o8u.pdb.gz).
# @> 2725 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5n67.pdb.gz).
# @> 2880 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5n68.pdb.gz).
# @> 2857 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5n66.pdb.gz).
# @> 2770 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5n65.pdb.gz).
# @> 2914 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5n63.pdb.gz).
# @> 2696 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5n64.pdb.gz).
# @> 2730 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5wp1.pdb.gz).
# @> 5908 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (6ges.pdb.gz).
# @> 3090 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> PDB file is found in working directory (6qal.pdb.gz).
# @> 3099 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6qaq.pdb.gz).
# @> 3150 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6qa4.pdb.gz).
# @> 3199 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6qa1.pdb.gz).
# @> 3203 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6qah.pdb.gz).
# @> 3048 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6nbs.pdb.gz).
# @> 3056 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6sfj.pdb.gz).
# @> 2954 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6una.pdb.gz).
# @> 2698 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> PDB file is found in working directory (6una.pdb.gz).
# 50 proteins fetched in 1.52 seconds
# @> 2708 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6rq4.pdb.gz).
# @> 3110 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6slg.pdb.gz).
# @> 2871 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6ohd.pdb.gz).
# @> 2759 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6sfi.pdb.gz).
# @> 3127 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6sfk.pdb.gz).
# @> 2995 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6sfo.pdb.gz).
# @> 2905 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6oph.pdb.gz).
# @> 2902 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6opg.pdb.gz).
# @> 3050 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6opi.pdb.gz).
# @> 2742 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6g9n.pdb.gz).
# @> 3471 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6g92.pdb.gz).
# @> 3363 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6g9a.pdb.gz).
# @> 3365 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6q7t.pdb.gz).
# @> 3114 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6q7s.pdb.gz).
# @> 3138 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6qa3.pdb.gz).
# @> 3121 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6ges.pdb.gz).
# @> 3051 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6hwt.pdb.gz).
# @> 3012 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6m9l.pdb.gz).
# @> 2843 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5omg.pdb.gz).
# @> 2903 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6hwu.pdb.gz).
# @> 2846 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5omh.pdb.gz).
# @> 2547 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6hwv.pdb.gz).
# @> 3085 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6m95.pdb.gz).
# @> 3018 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6qag.pdb.gz).
# @> 2989 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6q7k.pdb.gz).
# @> 3108 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6qaw.pdb.gz).
# @> 3128 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6d5y.pdb.gz).
# @> 2757 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6g54.pdb.gz).
# @> 3125 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6hkm.pdb.gz).
# @> 2711 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6hkn.pdb.gz).
# @> 2831 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6gjb.pdb.gz).
# @> 3343 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6gjd.pdb.gz).
# @> 3280 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6dmg.pdb.gz).
# @> 5799 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> PDB file is found in working directory (4z9l.pdb.gz).
# @> 2815 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6ekd.pdb.gz).
# @> 2678 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6eq9.pdb.gz).
# @> 3055 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6eq9.pdb.gz).
# @> 2789 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6emh.pdb.gz).
# @> 2855 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> PDB file is found in working directory (1bmk.pdb.gz).
# @> 2950 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1cm8.pdb.gz).
# @> 2703 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1jnk.pdb.gz).
# @> 3016 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1r39.pdb.gz).
# @> 2912 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1bl6.pdb.gz).
# @> 2927 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1bl7.pdb.gz).
# @> 2915 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5mz3.pdb.gz).
# @> 3105 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (1wfc.pdb.gz).
# @> 2932 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1di9.pdb.gz).
# @> 2859 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1pmu.pdb.gz).
# @> 2834 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5wjj.pdb.gz).
# @> 3126 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6anl.pdb.gz).
# @> 2981 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5xyy.pdb.gz).
# @> 2837 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5xyx.pdb.gz).
# 100 proteins fetched in 3.02 seconds
# @> 2749 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6f5e.pdb.gz).
# @> 5645 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (5lw1.pdb.gz).
# @> 2912 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> PDB file is found in working directory (5lw1.pdb.gz).
# @> 2912 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> PDB file is found in working directory (5lw1.pdb.gz).
# @> 2917 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> PDB file is found in working directory (1cm8.pdb.gz).
# @> 2739 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5mtx.pdb.gz).
# @> 2867 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (1pmv.pdb.gz).
# @> 2899 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5mty.pdb.gz).
# @> 2733 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1m7q.pdb.gz).
# @> 2952 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1r3c.pdb.gz).
# @> 3075 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5nhh.pdb.gz).
# @> 3055 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5v62.pdb.gz).
# @> 3191 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5v60.pdb.gz).
# @> 3009 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5v61.pdb.gz).
# @> 2978 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5nhf.pdb.gz).
# @> 2767 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5tco.pdb.gz).
# @> 2742 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5tbe.pdb.gz).
# @> 2706 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5nhp.pdb.gz).
# @> 2933 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5ngu.pdb.gz).
# @> 2756 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5nho.pdb.gz).
# @> 2807 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5nhj.pdb.gz).
# @> 2961 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5nhl.pdb.gz).
# @> 2881 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6emh.pdb.gz).
# @> 3055 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (6emh.pdb.gz).
# @> 3056 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (6emh.pdb.gz).
# @> 2868 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (5o7i.pdb.gz).
# @> 2859 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (1pmn.pdb.gz).
# @> 3004 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1ouy.pdb.gz).
# @> 2913 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1a9u.pdb.gz).
# @> 2950 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5etf.pdb.gz).
# @> 2947 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gcs.pdb.gz).
# @> 2881 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3nww.pdb.gz).
# @> 2984 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2no3.pdb.gz).
# @> 2894 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3v6s.pdb.gz).
# @> 2849 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3ds6.pdb.gz).
# @> 2822 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3nnw.pdb.gz).
# @> 3426 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4h3b.pdb.gz).
# @> 3032 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4h3b.pdb.gz).
# @> 3042 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (2lgc.pdb.gz).
# @> 3242 atoms and 10 coordinate set(s) were parsed in 0.06s.
# @> PDB file is found in working directory (3v6r.pdb.gz).
# @> 2957 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4yr8.pdb.gz).
# @> 2632 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (4yr8.pdb.gz).
# @> 2457 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (4yr8.pdb.gz).
# @> 2653 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (4yr8.pdb.gz).
# @> 2620 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (2r9s.pdb.gz).
# @> 2870 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2g01.pdb.gz).
# @> 2886 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4whz.pdb.gz).
# @> 3181 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3uvq.pdb.gz).
# 150 proteins fetched in 4.71 seconds
# @> 2779 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4iz5.pdb.gz).
# @> 2875 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (4iz5.pdb.gz).
# @> 2883 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (4kin.pdb.gz).
# @> 2886 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3zya.pdb.gz).
# @> 3129 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3hv6.pdb.gz).
# @> 2915 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5buj.pdb.gz).
# @> 3095 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gcq.pdb.gz).
# @> 2947 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2yix.pdb.gz).
# @> 3133 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1zzl.pdb.gz).
# @> 2981 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1kv1.pdb.gz).
# @> 2759 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4ux9.pdb.gz).
# @> 2914 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4ux9.pdb.gz).
# @> 2757 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4ux9.pdb.gz).
# @> 2804 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4ux9.pdb.gz).
# @> 2900 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4fmq.pdb.gz).
# @> 3075 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (2bal.pdb.gz).
# @> 2843 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1zyj.pdb.gz).
# @> 2865 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4iz7.pdb.gz).
# @> 3038 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1ove.pdb.gz).
# @> 3134 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3ocg.pdb.gz).
# @> 2875 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4kiq.pdb.gz).
# @> 2825 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4h36.pdb.gz).
# @> 2788 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3lhj.pdb.gz).
# @> 2783 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gcv.pdb.gz).
# @> 2943 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4zsj.pdb.gz).
# @> 3045 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4qp8.pdb.gz).
# @> 2838 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp8.pdb.gz).
# @> 2831 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3uvr.pdb.gz).
# @> 2854 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6g9h.pdb.gz).
# @> 3342 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5ml5.pdb.gz).
# @> 2821 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5lcj.pdb.gz).
# @> 3447 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5lck.pdb.gz).
# @> 3395 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3cgo.pdb.gz).
# @> 2784 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3cgf.pdb.gz).
# @> 2831 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5eko.pdb.gz).
# @> 3013 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5ekn.pdb.gz).
# @> 2787 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5k4i.pdb.gz).
# @> 3032 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4zxt.pdb.gz).
# @> 6019 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> PDB file is found in working directory (5byz.pdb.gz).
# @> 3210 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4zsg.pdb.gz).
# @> 3181 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4zsl.pdb.gz).
# @> 3068 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5byy.pdb.gz).
# @> 2782 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6g91.pdb.gz).
# @> 3298 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5ax3.pdb.gz).
# @> 2725 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5eti.pdb.gz).
# @> 2918 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5etc.pdb.gz).
# @> 3062 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4x21.pdb.gz).
# @> 2834 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4x21.pdb.gz).
# @> 2761 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp4.pdb.gz).
# @> 2919 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4xj0.pdb.gz).
# @> 2940 atoms and 1 coordinate set(s) were parsed in 0.03s.
# 200 proteins fetched in 6.18 seconds
# @> PDB file is found in working directory (3bv2.pdb.gz).
# @> 2862 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3qud.pdb.gz).
# @> 2937 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2i0h.pdb.gz).
# @> 3311 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4e5a.pdb.gz).
# @> 2892 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2xrw.pdb.gz).
# @> 3254 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2zb0.pdb.gz).
# @> 3131 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2gmx.pdb.gz).
# @> 2904 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4kiq.pdb.gz).
# @> 2861 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2waj.pdb.gz).
# @> 3010 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3tti.pdb.gz).
# @> 3032 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4o6e.pdb.gz).
# @> 2903 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4qta.pdb.gz).
# @> 3210 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4iza.pdb.gz).
# @> 2838 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4iza.pdb.gz).
# @> 3208 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4qp2.pdb.gz).
# @> 2834 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp2.pdb.gz).
# @> 2944 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp4.pdb.gz).
# @> 2910 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qpa.pdb.gz).
# @> 2858 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qpa.pdb.gz).
# @> 2736 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp1.pdb.gz).
# @> 2928 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp1.pdb.gz).
# @> 2922 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp6.pdb.gz).
# @> 2751 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp6.pdb.gz).
# @> 2805 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp7.pdb.gz).
# @> 2832 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp7.pdb.gz).
# @> 2832 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp3.pdb.gz).
# @> 2906 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp3.pdb.gz).
# @> 2797 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4qp9.pdb.gz).
# @> 2869 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5bve.pdb.gz).
# @> 3016 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4xj0.pdb.gz).
# @> 2848 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5bvf.pdb.gz).
# @> 2943 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5bvd.pdb.gz).
# @> 3044 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1oz1.pdb.gz).
# @> 2999 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3hv5.pdb.gz).
# @> 2954 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1wbs.pdb.gz).
# @> 3268 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3hv5.pdb.gz).
# @> 2936 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3l8x.pdb.gz).
# @> 2652 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fkl.pdb.gz).
# @> 2968 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3mvl.pdb.gz).
# @> 2829 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2zaz.pdb.gz).
# @> 3189 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2zb1.pdb.gz).
# @> 3077 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4kin.pdb.gz).
# @> 3058 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (2no3.pdb.gz).
# @> 2903 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3lfe.pdb.gz).
# @> 2817 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fmj.pdb.gz).
# @> 3038 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2p33.pdb.gz).
# @> 2775 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3v6s.pdb.gz).
# @> 2913 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (2zdt.pdb.gz).
# @> 2974 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2zdu.pdb.gz).
# @> 2774 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fi2.pdb.gz).
# @> 2868 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gc9.pdb.gz).
# @> 2900 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3i60.pdb.gz).
# 250 proteins fetched in 7.65 seconds
# @> 2910 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4fv1.pdb.gz).
# @> 3063 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4g6n.pdb.gz).
# @> 2978 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6gdm.pdb.gz).
# @> 3311 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3e7o.pdb.gz).
# @> 2916 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6g93.pdb.gz).
# @> 3268 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4ic7.pdb.gz).
# @> 2842 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6ge0.pdb.gz).
# @> 3319 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6g97.pdb.gz).
# @> 3355 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6g8x.pdb.gz).
# @> 3249 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2fsl.pdb.gz).
# @> 2897 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3ody.pdb.gz).
# @> 2636 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3rin.pdb.gz).
# @> 2939 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3mpt.pdb.gz).
# @> 3158 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3o8u.pdb.gz).
# @> 2926 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3heg.pdb.gz).
# @> 2828 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gc7.pdb.gz).
# @> 3296 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3hv7.pdb.gz).
# @> 2817 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4kin.pdb.gz).
# @> 2989 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3ha8.pdb.gz).
# @> 2823 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2gfs.pdb.gz).
# @> 3100 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3hv3.pdb.gz).
# @> 2881 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gi3.pdb.gz).
# @> 2892 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1wbn.pdb.gz).
# @> 3414 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3d7z.pdb.gz).
# @> 3220 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1kv2.pdb.gz).
# @> 2656 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4e5b.pdb.gz).
# @> 2704 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3ctq.pdb.gz).
# @> 2890 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3oef.pdb.gz).
# @> 3067 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2rg5.pdb.gz).
# @> 2768 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2onl.pdb.gz).
# @> 2709 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3obg.pdb.gz).
# @> 2727 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2fst.pdb.gz).
# @> 3116 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4aa0.pdb.gz).
# @> 2997 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3u8w.pdb.gz).
# @> 2915 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fmk.pdb.gz).
# @> 3195 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2baj.pdb.gz).
# @> 2851 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3flz.pdb.gz).
# @> 3034 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2qd9.pdb.gz).
# @> 2850 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3ds6.pdb.gz).
# @> 2870 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> PDB file is found in working directory (2npq.pdb.gz).
# @> 3014 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> PDB file is found in working directory (2baq.pdb.gz).
# @> 2701 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3fmn.pdb.gz).
# @> 3151 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3kf7.pdb.gz).
# @> 2890 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3iw8.pdb.gz).
# @> 2915 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4geo.pdb.gz).
# @> 2948 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1wbw.pdb.gz).
# @> 3119 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4aa5.pdb.gz).
# @> 2803 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3mvm.pdb.gz).
# @> 2917 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fmm.pdb.gz).
# @> 3053 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3zsh.pdb.gz).
# @> 2935 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4kip.pdb.gz).
# 300 proteins fetched in 8.98 seconds
# @> 2735 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gcu.pdb.gz).
# @> 2914 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3bv3.pdb.gz).
# @> 2869 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3hrb.pdb.gz).
# @> 2971 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gcp.pdb.gz).
# @> 2910 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3s3i.pdb.gz).
# @> 3056 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3flq.pdb.gz).
# @> 2961 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3o8t.pdb.gz).
# @> 2879 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4kiq.pdb.gz).
# @> 2896 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3iw6.pdb.gz).
# @> 2924 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3lfc.pdb.gz).
# @> 2757 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3itz.pdb.gz).
# @> 3006 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2okr.pdb.gz).
# @> 2813 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3iph.pdb.gz).
# @> 3213 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4kin.pdb.gz).
# @> 2972 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4kip.pdb.gz).
# @> 2719 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3flw.pdb.gz).
# @> 3091 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1zz2.pdb.gz).
# @> 2872 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fl4.pdb.gz).
# @> 3116 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3hec.pdb.gz).
# @> 2814 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3uvp.pdb.gz).
# @> 2799 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1yqj.pdb.gz).
# @> 3055 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3lff.pdb.gz).
# @> 2991 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gcu.pdb.gz).
# @> 2968 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3s4q.pdb.gz).
# @> 2651 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1ouk.pdb.gz).
# @> 2984 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3od6.pdb.gz).
# @> 2823 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1wbv.pdb.gz).
# @> 3450 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3mgy.pdb.gz).
# @> 2737 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1w82.pdb.gz).
# @> 3388 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3mh0.pdb.gz).
# @> 2787 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3mh3.pdb.gz).
# @> 2766 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3ds6.pdb.gz).
# @> 2870 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3dt1.pdb.gz).
# @> 2946 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3pg3.pdb.gz).
# @> 2868 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fls.pdb.gz).
# @> 2836 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3zsg.pdb.gz).
# @> 3086 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2okr.pdb.gz).
# @> 2807 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fc1.pdb.gz).
# @> 2837 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fly.pdb.gz).
# @> 3113 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3que.pdb.gz).
# @> 2849 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3lfd.pdb.gz).
# @> 2716 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2fso.pdb.gz).
# @> 3109 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3hv4.pdb.gz).
# @> 2898 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fsf.pdb.gz).
# @> 2941 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3huc.pdb.gz).
# @> 2988 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3nnu.pdb.gz).
# @> 3013 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fln.pdb.gz).
# @> 3153 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3mvl.pdb.gz).
# @> 2838 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2bak.pdb.gz).
# 350 proteins fetched in 10.19 seconds
# @> 2819 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1w84.pdb.gz).
# @> 3427 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3iw5.pdb.gz).
# @> 2851 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3ds6.pdb.gz).
# @> 2822 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4a9y.pdb.gz).
# @> 2819 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1wbt.pdb.gz).
# @> 3121 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3kq7.pdb.gz).
# @> 3257 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fko.pdb.gz).
# @> 3080 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3mw1.pdb.gz).
# @> 2794 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2fsm.pdb.gz).
# @> 2856 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3o8p.pdb.gz).
# @> 3030 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4aac.pdb.gz).
# @> 2884 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4aa4.pdb.gz).
# @> 2861 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3hv4.pdb.gz).
# @> 2839 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2y8o.pdb.gz).
# @> 3027 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fi4.pdb.gz).
# @> 2941 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3l8s.pdb.gz).
# @> 2770 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fkn.pdb.gz).
# @> 3103 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3zsi.pdb.gz).
# @> 2812 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3odz.pdb.gz).
# @> 2772 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3nnv.pdb.gz).
# @> 3107 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3iw7.pdb.gz).
# @> 2900 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3hub.pdb.gz).
# @> 2846 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2onl.pdb.gz).
# @> 2714 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3nnx.pdb.gz).
# @> 2915 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3bx5.pdb.gz).
# @> 2789 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3d83.pdb.gz).
# @> 3291 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3mpa.pdb.gz).
# @> 2867 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4l8m.pdb.gz).
# @> 2850 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1w7h.pdb.gz).
# @> 3317 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fmh.pdb.gz).
# @> 3076 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3oc1.pdb.gz).
# @> 2736 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3lfa.pdb.gz).
# @> 2874 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3mh1.pdb.gz).
# @> 2794 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fml.pdb.gz).
# @> 2960 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fsk.pdb.gz).
# @> 2915 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4kiq.pdb.gz).
# @> 2871 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (1wbo.pdb.gz).
# @> 3171 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3lfb.pdb.gz).
# @> 2752 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3obj.pdb.gz).
# @> 2832 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gfe.pdb.gz).
# @> 2992 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3zs5.pdb.gz).
# @> 3106 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3mh2.pdb.gz).
# @> 2733 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3mvm.pdb.gz).
# @> 2912 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1w83.pdb.gz).
# @> 3234 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6g9j.pdb.gz).
# @> 3322 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6g9d.pdb.gz).
# @> 3358 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3pze.pdb.gz).
# @> 3031 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4izy.pdb.gz).
# @> 2708 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3vud.pdb.gz).
# @> 2863 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3o17.pdb.gz).
# 400 proteins fetched in 11.45 seconds
# @> 2895 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4qtd.pdb.gz).
# @> 3399 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3v3v.pdb.gz).
# @> 2859 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3o17.pdb.gz).
# @> 2895 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2g01.pdb.gz).
# @> 2886 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3elj.pdb.gz).
# @> 3142 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2h96.pdb.gz).
# @> 2926 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3vum.pdb.gz).
# @> 2897 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4awi.pdb.gz).
# @> 3158 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4l7f.pdb.gz).
# @> 3380 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3vuh.pdb.gz).
# @> 2924 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4hys.pdb.gz).
# @> 2656 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2h96.pdb.gz).
# @> 2927 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3vui.pdb.gz).
# @> 2900 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3vug.pdb.gz).
# @> 2906 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2gmx.pdb.gz).
# @> 2905 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3vuk.pdb.gz).
# @> 2887 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3vul.pdb.gz).
# @> 2811 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2xs0.pdb.gz).
# @> 2846 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4g1w.pdb.gz).
# @> 2680 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1uki.pdb.gz).
# @> 2679 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4hyu.pdb.gz).
# @> 2709 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1ukh.pdb.gz).
# @> 2679 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6gdq.pdb.gz).
# @> 3085 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (6g9m.pdb.gz).
# @> 3347 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (6g9k.pdb.gz).
# @> 3298 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3g90.pdb.gz).
# @> 2887 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2ok1.pdb.gz).
# @> 2832 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3rtp.pdb.gz).
# @> 2735 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2exc.pdb.gz).
# @> 2840 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3ptg.pdb.gz).
# @> 2810 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4h39.pdb.gz).
# @> 2846 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3ttj.pdb.gz).
# @> 2893 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3oy1.pdb.gz).
# @> 2918 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2o2u.pdb.gz).
# @> 2680 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2b1p.pdb.gz).
# @> 2919 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4u79.pdb.gz).
# @> 2811 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fv8.pdb.gz).
# @> 2877 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3da6.pdb.gz).
# @> 2757 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4w4y.pdb.gz).
# @> 3027 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4kke.pdb.gz).
# @> 2994 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2o0u.pdb.gz).
# @> 2899 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4kkg.pdb.gz).
# @> 2897 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3fi3.pdb.gz).
# @> 2922 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3kvx.pdb.gz).
# @> 2595 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3v6r.pdb.gz).
# @> 2906 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4w4w.pdb.gz).
# @> 3144 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (3g9l.pdb.gz).
# @> 2876 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4y46.pdb.gz).
# @> 5666 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> PDB file is found in working directory (3g9n.pdb.gz).
# 450 proteins fetched in 12.72 seconds
# @> 2841 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4y5h.pdb.gz).
# @> 5727 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> PDB file is found in working directory (3oxi.pdb.gz).
# @> 2724 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4kkh.pdb.gz).
# @> 3042 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4w4v.pdb.gz).
# @> 3130 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4w4x.pdb.gz).
# @> 2975 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2r9s.pdb.gz).
# @> 2799 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4eym.pdb.gz).
# @> 2906 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4myg.pdb.gz).
# @> 2848 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4yno.pdb.gz).
# @> 3092 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3coi.pdb.gz).
# @> 2920 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4eyj.pdb.gz).
# @> 3052 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4myg.pdb.gz).
# @> 2810 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gc9.pdb.gz).
# @> 2905 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gp0.pdb.gz).
# @> 2898 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gc8.pdb.gz).
# @> 2880 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3gc8.pdb.gz).
# @> 2874 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4fv7.pdb.gz).
# @> 3095 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4zzm.pdb.gz).
# @> 2865 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4zzo.pdb.gz).
# @> 2970 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (2y9q.pdb.gz).
# @> 3396 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (1wzy.pdb.gz).
# @> 3116 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4fv8.pdb.gz).
# @> 3011 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4fv4.pdb.gz).
# @> 2732 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4fuy.pdb.gz).
# @> 2942 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4h3p.pdb.gz).
# @> 2857 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4fv3.pdb.gz).
# @> 3038 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4iz7.pdb.gz).
# @> 3069 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4nif.pdb.gz).
# @> 3176 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> PDB file is found in working directory (4h3p.pdb.gz).
# @> 2830 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4zzn.pdb.gz).
# @> 3143 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1tvo.pdb.gz).
# @> 3020 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4nif.pdb.gz).
# @> 3198 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (4h3q.pdb.gz).
# @> 2929 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4fv0.pdb.gz).
# @> 3026 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4fv5.pdb.gz).
# @> 2883 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2ojj.pdb.gz).
# @> 2910 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4fv2.pdb.gz).
# @> 3067 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3i5z.pdb.gz).
# @> 2910 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4n0s.pdb.gz).
# @> 6165 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> PDB file is found in working directory (4iz5.pdb.gz).
# @> 2879 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (3tei.pdb.gz).
# @> 2868 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4qte.pdb.gz).
# @> 3455 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4fv9.pdb.gz).
# @> 2912 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5bue.pdb.gz).
# @> 2846 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (1pme.pdb.gz).
# @> 2973 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2oji.pdb.gz).
# @> 2941 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3sa0.pdb.gz).
# @> 6115 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> PDB file is found in working directory (3w55.pdb.gz).
# @> 2842 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2ojg.pdb.gz).
# @> 2970 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4g6o.pdb.gz).
# @> 3000 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4fux.pdb.gz).
# 500 proteins fetched in 14.24 seconds
# @> 2985 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4iz5.pdb.gz).
# @> 2883 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> PDB file is found in working directory (4fv6.pdb.gz).
# @> 2820 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (5bui.pdb.gz).
# @> 3062 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4qtb.pdb.gz).
# @> 3452 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (2zoq.pdb.gz).
# @> 3052 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4qtb.pdb.gz).
# @> 3544 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (2zoq.pdb.gz).
# @> 3050 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (2i6l.pdb.gz).
# @> 1984 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> PDB file is found in working directory (2i6l.pdb.gz).
# @> 2180 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3npc.pdb.gz).
# @> 3064 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3npc.pdb.gz).
# @> 3066 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (3e7o.pdb.gz).
# @> 2775 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4b99.pdb.gz).
# @> 2659 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4ic8.pdb.gz).
# @> 2375 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> PDB file is found in working directory (4ic7.pdb.gz).
# @> 2738 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (4ic8.pdb.gz).
# @> 2432 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5eta.pdb.gz).
# @> 2713 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5eta.pdb.gz).
# @> 2718 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> PDB file is found in working directory (5nhv.pdb).
# @> 2975 atoms and 1 coordinate set(s) were parsed in 0.02s.

# %%
from geometricus import MomentInvariants, SplitType, MomentType

invariants_kmer = []
invariants_kmer2 = []
invariants_radius = []

start_time = time()
for i, key in enumerate(X_names):
    if i > 0 and i % 50 == 0:
        print(f"{i} proteins in {(time() - start_time):.2f} seconds")
    invariants_kmer.append(MomentInvariants.from_prody_atomgroup(key, pdbs[i], split_type=SplitType.KMER, split_size=6, moment_types=list(MomentType)))
    invariants_kmer2.append(MomentInvariants.from_prody_atomgroup(key, pdbs[i], split_type=SplitType.KMER, split_size=12, moment_types=list(MomentType)))
    invariants_radius.append(MomentInvariants.from_prody_atomgroup(key, pdbs[i], split_type=SplitType.RADIUS, split_size=10, moment_types=list(MomentType)))
# Out:
# 50 proteins in 9.14 seconds
# 100 proteins in 12.14 seconds
# 150 proteins in 15.28 seconds
# 200 proteins in 18.39 seconds
# 250 proteins in 21.36 seconds
# 300 proteins in 24.53 seconds
# 350 proteins in 27.55 seconds
# 400 proteins in 30.53 seconds
# 450 proteins in 33.73 seconds
# 500 proteins in 36.69 seconds

# %%
ind_moments_kmer = [((np.sign(x.moments) * np.log1p(np.abs(x.moments))) / 6).astype("float32") for x in invariants_kmer]
ind_moments_kmer2 = [((np.sign(x.moments) * np.log1p(np.abs(x.moments))) / 12).astype("float32") for x in invariants_kmer2]
ind_moments_radius = [((np.sign(x.moments) * np.log1p(np.abs(x.moments))) / 10).astype("float32") for x in invariants_radius]
ind_moments = [np.hstack((ind_moments_kmer[i], ind_moments_kmer2[i], ind_moments_radius[i])) for i in range(len(ind_moments_radius))]

# %%
def unpack_and_desort(x, sizes, desort_idx):
    x, sizes = torch.nn.utils.rnn.pad_packed_sequence(x, batch_first=True)
    x = x[np.arange(x.shape[0]), sizes-1]
    x = x[np.argsort(desort_idx)]
    return x

# %%
from MomentLearn.model import LinearMoment, ContrastiveLearn, RNNMoment, sample_double_proteins_with_sim_dist, loss_func

batch_size = 150 
rnn_model = LSTMMoment(2, len(ind_moments[0][0]), 5, 2, batch_size=batch_size)
optimizer = torch.optim.Adam(rnn_model.parameters(), lr=0.0005)
epoch = 400

# %%
current_losses = []
rnn_model.batch_size = batch_size
for e in range(epoch):
    (x1, sizes1, sort_idx1), (x2, sizes2, sort_idx2), which = sample_double_proteins_with_sim_dist(ind_moments, np.array(mapping), batch=batch_size)
    hidden_batch11, cell_batch12 = rnn_model.init_hidden()
    hidden_batch21, cell_batch22 = rnn_model.init_hidden()
    (x1, (h1, c1)), (x2, (h2, c2)) = rnn_model(x1, x2, hidden_batch11, hidden_batch21, cell_batch12, cell_batch22, sizes1, sizes2)
#     break
    x1, x2 = h1[-1][np.argsort(sort_idx1)], h2[-1][np.argsort(sort_idx2)]
#     x1 = unpack_and_desort(x1, sizes1, sort_idx1)
#     x2 = unpack_and_desort(x2, sizes2, sort_idx2)
    loss = loss_func(x1, x2, which)
    optimizer.zero_grad()
    loss.backward()
    current_losses.append(loss.item())
    optimizer.step()

    if e % 50 == 0:
        print(np.mean(current_losses))
        current_losses = []
# Out:
# 0.03670612350106239
# 0.02961456388235092
# 0.02957928329706192
# 0.03121219575405121
# 0.028507611826062203
# 0.027740571722388266
# 0.02678492747247219
# 0.025875803921371697

# %%
sizes = np.array([len(x) for x in ind_moments])
sort_idx = np.argsort(sizes)[::-1]
sizes = sizes[sort_idx]
all_moments = torch.tensor(np.concatenate(np.array(ind_moments)[sort_idx]).astype("float32"))
rnn_model.batch_size = len(ind_moments)
hidden1, hidden2 = rnn_model.init_hidden()
res = rnn_model.forward_single(all_moments, hidden1, hidden2, sizes)
res = res[1][0][-1].detach().cpu().numpy()[np.argsort(sort_idx)]

# %%
reducer = umap.UMAP(metric="cosine", n_components=2, n_neighbors=20)
reduced = reducer.fit_transform(res)
# reduced = res
plt.figure(figsize=(10,10))
for i in range(3):
    indices = np.where(np.array(mapping) == i)[0]
    plt.scatter(reduced[indices, 0],
                reduced[indices, 1],
                edgecolor="black",
                linewidth=0.1,
                alpha=0.8)
plt.axis("off")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
proteins = [rnn_model.linear_moment(torch.tensor(x.astype("float32"))).cpu().detach().numpy() for x in ind_moments]
residue_coords = [x.coordinates for x in invariants_kmer]

# %%
i1 = 3
i2 = -1
protein_a = proteins[i1]
protein_b = proteins[i2]
coords_a = residue_coords[i1]
coords_b = residue_coords[i2]

# %%
def svd_superimpose(coords_1, coords_2):
    centroid_1, centroid_2 = (
        helper.nb_mean_axis_0(coords_1),
        helper.nb_mean_axis_0(coords_2),
    )
    coords_1_c, coords_2_c = coords_1 - centroid_1, coords_2 - centroid_2
    correlation_matrix = np.dot(coords_2_c.T, coords_1_c)
    u, s, v = np.linalg.svd(correlation_matrix)
    reflect = np.linalg.det(u) * np.linalg.det(v) < 0
    if reflect:
        s[-1] = -s[-1]
        u[:, -1] = -u[:, -1]
    rotation_matrix = np.dot(u, v)
    translation_matrix = centroid_1 - np.dot(centroid_2, rotation_matrix)
    return rotation_matrix.astype(np.float64), translation_matrix.astype(np.float64)

# %%
score_matrix = np.array([[np.abs(x - y).sum() for y in protein_b] for x in protein_a])
score_matrix = score_matrix.max() - score_matrix
p1_idx, p2_idx, _ = dtw.dtw_align(score_matrix, gap_open_penalty=3.5, gap_extend_penalty=2)

# %%
def score(coords1, coords2, gamma=2):
    rot, trans = svd_superimpose(np.array(coords1).astype(float), np.array(coords2).astype(float))
    coords2_rotated = np.dot(coords2 - np.mean(coords2, axis=0), rot)
    coords1_translated = coords1 - np.mean(coords1, axis=0)
    return get_caretta_score(coords1_translated, coords2_rotated).mean(), (coords1_translated, coords2_rotated)

core_p1_idx, core_p2_idx = helper.get_common_positions(p1_idx, p2_idx)
aligned_score, (p1_rotated_common, p2_rotated_common) = score(coords_a[core_p1_idx], coords_b[core_p2_idx])
unaligned_score, _ = score(coords_a[:min(coords_a.shape[0], coords_b.shape[0])], coords_b[:min(coords_a.shape[0], coords_b.shape[0])])
aligned_score, unaligned_score
# Out:
# (0.8231203696234228, 0.036702942631759244)

# %%
def fill_gaps_for_plotting(alignment_idx):
    while np.where(alignment_idx == -1)[0].shape[0] != 0:
        current = np.where(alignment_idx == -1)[0][0]
        if current == 0:
            alignment_idx[current] = alignment_idx[np.where(alignment_idx != -1)[0][0]]
        else:
            alignment_idx[current] = alignment_idx[current - 1]
    return alignment_idx

# %%
p1_idx_filled, p2_idx_filled = fill_gaps_for_plotting(p1_idx), fill_gaps_for_plotting(p2_idx)

# %%
plt.figure(figsize=(20,3))
plt.plot(protein_a, lw=3, alpha=.7, c="r", label="Protein A")
plt.plot(protein_b, lw=3, alpha=.7, c="b", label="Protein B")
plt.title(f"Without alignment Caretta-score: {unaligned_score:.4f}")
plt.legend()
plt.show()
plt.figure(figsize=(20,3))
plt.plot(protein_a[p1_idx_filled], lw=3, alpha=.7, c="r", label="Protein A")
plt.plot(protein_b[p2_idx_filled], lw=3, alpha=.7, c="b", label="Protein B")
plt.title(f"With alignment Caretta-score: {aligned_score:.4f}")
plt.legend()
plt.show()
